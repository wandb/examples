# %%
from fastcore.all import *
from ghapi.all import *
from nb_helpers.utils import *

# %%
token = "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"

# %%
api = GhApi(owner='wandb', repo='examples', token=token)

# %%
issue = 225
# api.issues.create_comment(issue_number=pr_n, body="Adding a comment programatically")

# %%
pr = api.pulls.get(issue)

# %%
pr
# Out:
# - url: https://api.github.com/repos/wandb/examples/pulls/225
# - id: 898617276
# - node_id: PR_kwDOBx4xQs41j8-8
# - html_url: https://github.com/wandb/examples/pull/225
# - diff_url: https://github.com/wandb/examples/pull/225.diff
# - patch_url: https://github.com/wandb/examples/pull/225.patch
# - issue_url: https://api.github.com/repos/wandb/examples/issues/225
# - number: 225
# - state: open
# - locked: False
# - title: ConvNext + MMDetection integration colabs
# - user:
#   - login: ayulockin
#   - id: 31141479
#   - node_id: MDQ6VXNlcjMxMTQxNDc5
#   - avatar_url: https://avatars.githubusercontent.com/u/31141479?v=4
#   - gravatar_id:
#   - url: https://api.github.com/users/ayulockin
#   - html_url: https://github.com/ayulockin
#   - followers_url: https://api.github.com/users/ayulockin/followers
#   - following_url: https://api.github.com/users/ayulockin/following{/other_user}
#   - gists_url: https://api.github.com/users/ayulockin/gists{/gist_id}
#   - starred_url: https://api.github.com/users/ayulockin/starred{/owner}{/repo}
#   - subscriptions_url: https://api.github.com/users/ayulockin/subscriptions
#   - organizations_url: https://api.github.com/users/ayulockin/orgs
#   - repos_url: https://api.github.com/users/ayulockin/repos
#   - events_url: https://api.github.com/users/ayulockin/events{/privacy}
#   - received_events_url: https://api.github.com/users/ayulockin/received_events
#   - type: User
#   - site_admin: False
# - body: Add colab notebooks to showcase our ConvNext and MMDetection integrations.
#
# Note: I have added a new directory `integrations` under `colabs` dir. The idea is to add the colabs for each integration in respective subdirs inside `integrations`.
# - created_at: 2022-04-04T06:28:57Z
# - updated_at: 2022-04-04T08:56:57Z
# - closed_at: None
# - merged_at: None
# - merge_commit_sha: 9ef0357e23b67a2bc83035939a63bff17a97f9fe
# - assignee: None
# - assignees:
#
# - requested_reviewers:
#
# - requested_teams:
#
# - labels:
#
# - milestone: None
# - draft: False
# - commits_url: https://api.github.com/repos/wandb/examples/pulls/225/commits
# - review_comments_url: https://api.github.com/repos/wandb/examples/pulls/225/comments
# - review_comment_url: https://api.github.com/repos/wandb/examples/pulls/comments{/number}
# - comments_url: https://api.github.com/repos/wandb/examples/issues/225/comments
# - statuses_url: https://api.github.com/repos/wandb/examples/statuses/e05578363b4ae1fb7c3e8bfd005facd510d8eef3
# - head:
#   - label: ayulockin:master
#   - ref: master
#   - sha: e05578363b4ae1fb7c3e8bfd005facd510d8eef3
#   - user:
#     - login: ayulockin
#     - id: 31141479
#     - node_id: MDQ6VXNlcjMxMTQxNDc5
#     - avatar_url: https://avatars.githubusercontent.com/u/31141479?v=4
#     - gravatar_id:
#     - url: https://api.github.com/users/ayulockin
#     - html_url: https://github.com/ayulockin
#     - followers_url: https://api.github.com/users/ayulockin/followers
#     - following_url: https://api.github.com/users/ayulockin/following{/other_user}
#     - gists_url: https://api.github.com/users/ayulockin/gists{/gist_id}
#     - starred_url: https://api.github.com/users/ayulockin/starred{/owner}{/repo}
#     - subscriptions_url: https://api.github.com/users/ayulockin/subscriptions
#     - organizations_url: https://api.github.com/users/ayulockin/orgs
#     - repos_url: https://api.github.com/users/ayulockin/repos
#     - events_url: https://api.github.com/users/ayulockin/events{/privacy}
#     - received_events_url: https://api.github.com/users/ayulockin/received_events
#     - type: User
#     - site_admin: False
#   - repo:
#     - id: 477574208
#     - node_id: R_kgDOHHc0QA
#     - name: examples
#     - full_name: ayulockin/examples
#     - private: False
#     - owner:
#       - login: ayulockin
#       - id: 31141479
#       - node_id: MDQ6VXNlcjMxMTQxNDc5
#       - avatar_url: https://avatars.githubusercontent.com/u/31141479?v=4
#       - gravatar_id:
#       - url: https://api.github.com/users/ayulockin
#       - html_url: https://github.com/ayulockin
#       - followers_url: https://api.github.com/users/ayulockin/followers
#       - following_url: https://api.github.com/users/ayulockin/following{/other_user}
#       - gists_url: https://api.github.com/users/ayulockin/gists{/gist_id}
#       - starred_url: https://api.github.com/users/ayulockin/starred{/owner}{/repo}
#       - subscriptions_url: https://api.github.com/users/ayulockin/subscriptions
#       - organizations_url: https://api.github.com/users/ayulockin/orgs
#       - repos_url: https://api.github.com/users/ayulockin/repos
#       - events_url: https://api.github.com/users/ayulockin/events{/privacy}
#       - received_events_url: https://api.github.com/users/ayulockin/received_events
#       - type: User
#       - site_admin: False
#     - html_url: https://github.com/ayulockin/examples
#     - description: Example deep learning projects that use wandb's features.
#     - fork: True
#     - url: https://api.github.com/repos/ayulockin/examples
#     - forks_url: https://api.github.com/repos/ayulockin/examples/forks
#     - keys_url: https://api.github.com/repos/ayulockin/examples/keys{/key_id}
#     - collaborators_url: https://api.github.com/repos/ayulockin/examples/collaborators{/collaborator}
#     - teams_url: https://api.github.com/repos/ayulockin/examples/teams
#     - hooks_url: https://api.github.com/repos/ayulockin/examples/hooks
#     - issue_events_url: https://api.github.com/repos/ayulockin/examples/issues/events{/number}
#     - events_url: https://api.github.com/repos/ayulockin/examples/events
#     - assignees_url: https://api.github.com/repos/ayulockin/examples/assignees{/user}
#     - branches_url: https://api.github.com/repos/ayulockin/examples/branches{/branch}
#     - tags_url: https://api.github.com/repos/ayulockin/examples/tags
#     - blobs_url: https://api.github.com/repos/ayulockin/examples/git/blobs{/sha}
#     - git_tags_url: https://api.github.com/repos/ayulockin/examples/git/tags{/sha}
#     - git_refs_url: https://api.github.com/repos/ayulockin/examples/git/refs{/sha}
#     - trees_url: https://api.github.com/repos/ayulockin/examples/git/trees{/sha}
#     - statuses_url: https://api.github.com/repos/ayulockin/examples/statuses/{sha}
#     - languages_url: https://api.github.com/repos/ayulockin/examples/languages
#     - stargazers_url: https://api.github.com/repos/ayulockin/examples/stargazers
#     - contributors_url: https://api.github.com/repos/ayulockin/examples/contributors
#     - subscribers_url: https://api.github.com/repos/ayulockin/examples/subscribers
#     - subscription_url: https://api.github.com/repos/ayulockin/examples/subscription
#     - commits_url: https://api.github.com/repos/ayulockin/examples/commits{/sha}
#     - git_commits_url: https://api.github.com/repos/ayulockin/examples/git/commits{/sha}
#     - comments_url: https://api.github.com/repos/ayulockin/examples/comments{/number}
#     - issue_comment_url: https://api.github.com/repos/ayulockin/examples/issues/comments{/number}
#     - contents_url: https://api.github.com/repos/ayulockin/examples/contents/{+path}
#     - compare_url: https://api.github.com/repos/ayulockin/examples/compare/{base}...{head}
#     - merges_url: https://api.github.com/repos/ayulockin/examples/merges
#     - archive_url: https://api.github.com/repos/ayulockin/examples/{archive_format}{/ref}
#     - downloads_url: https://api.github.com/repos/ayulockin/examples/downloads
#     - issues_url: https://api.github.com/repos/ayulockin/examples/issues{/number}
#     - pulls_url: https://api.github.com/repos/ayulockin/examples/pulls{/number}
#     - milestones_url: https://api.github.com/repos/ayulockin/examples/milestones{/number}
#     - notifications_url: https://api.github.com/repos/ayulockin/examples/notifications{?since,all,participating}
#     - labels_url: https://api.github.com/repos/ayulockin/examples/labels{/name}
#     - releases_url: https://api.github.com/repos/ayulockin/examples/releases{/id}
#     - deployments_url: https://api.github.com/repos/ayulockin/examples/deployments
#     - created_at: 2022-04-04T06:21:52Z
#     - updated_at: 2022-04-04T06:23:26Z
#     - pushed_at: 2022-04-04T06:25:49Z
#     - git_url: git://github.com/ayulockin/examples.git
#     - ssh_url: git@github.com:ayulockin/examples.git
#     - clone_url: https://github.com/ayulockin/examples.git
#     - svn_url: https://github.com/ayulockin/examples
#     - homepage: http://wandb.ai
#     - size: 117640
#     - stargazers_count: 0
#     - watchers_count: 0
#     - language: Jupyter Notebook
#     - has_issues: False
#     - has_projects: True
#     - has_downloads: True
#     - has_wiki: True
#     - has_pages: False
#     - forks_count: 0
#     - mirror_url: None
#     - archived: False
#     - disabled: False
#     - open_issues_count: 0
#     - license: None
#     - allow_forking: True
#     - is_template: False
#     - topics:
#
#     - visibility: public
#     - forks: 0
#     - open_issues: 0
#     - watchers: 0
#     - default_branch: master
# - base:
#   - label: wandb:master
#   - ref: master
#   - sha: f4337444bca1069214c7565196510472a53f9a56
#   - user:
#     - login: wandb
#     - id: 26401354
#     - node_id: MDEyOk9yZ2FuaXphdGlvbjI2NDAxMzU0
#     - avatar_url: https://avatars.githubusercontent.com/u/26401354?v=4
#     - gravatar_id:
#     - url: https://api.github.com/users/wandb
#     - html_url: https://github.com/wandb
#     - followers_url: https://api.github.com/users/wandb/followers
#     - following_url: https://api.github.com/users/wandb/following{/other_user}
#     - gists_url: https://api.github.com/users/wandb/gists{/gist_id}
#     - starred_url: https://api.github.com/users/wandb/starred{/owner}{/repo}
#     - subscriptions_url: https://api.github.com/users/wandb/subscriptions
#     - organizations_url: https://api.github.com/users/wandb/orgs
#     - repos_url: https://api.github.com/users/wandb/repos
#     - events_url: https://api.github.com/users/wandb/events{/privacy}
#     - received_events_url: https://api.github.com/users/wandb/received_events
#     - type: Organization
#     - site_admin: False
#   - repo:
#     - id: 119419202
#     - node_id: MDEwOlJlcG9zaXRvcnkxMTk0MTkyMDI=
#     - name: examples
#     - full_name: wandb/examples
#     - private: False
#     - owner:
#       - login: wandb
#       - id: 26401354
#       - node_id: MDEyOk9yZ2FuaXphdGlvbjI2NDAxMzU0
#       - avatar_url: https://avatars.githubusercontent.com/u/26401354?v=4
#       - gravatar_id:
#       - url: https://api.github.com/users/wandb
#       - html_url: https://github.com/wandb
#       - followers_url: https://api.github.com/users/wandb/followers
#       - following_url: https://api.github.com/users/wandb/following{/other_user}
#       - gists_url: https://api.github.com/users/wandb/gists{/gist_id}
#       - starred_url: https://api.github.com/users/wandb/starred{/owner}{/repo}
#       - subscriptions_url: https://api.github.com/users/wandb/subscriptions
#       - organizations_url: https://api.github.com/users/wandb/orgs
#       - repos_url: https://api.github.com/users/wandb/repos
#       - events_url: https://api.github.com/users/wandb/events{/privacy}
#       - received_events_url: https://api.github.com/users/wandb/received_events
#       - type: Organization
#       - site_admin: False
#     - html_url: https://github.com/wandb/examples
#     - description: Example deep learning projects that use wandb's features.
#     - fork: False
#     - url: https://api.github.com/repos/wandb/examples
#     - forks_url: https://api.github.com/repos/wandb/examples/forks
#     - keys_url: https://api.github.com/repos/wandb/examples/keys{/key_id}
#     - collaborators_url: https://api.github.com/repos/wandb/examples/collaborators{/collaborator}
#     - teams_url: https://api.github.com/repos/wandb/examples/teams
#     - hooks_url: https://api.github.com/repos/wandb/examples/hooks
#     - issue_events_url: https://api.github.com/repos/wandb/examples/issues/events{/number}
#     - events_url: https://api.github.com/repos/wandb/examples/events
#     - assignees_url: https://api.github.com/repos/wandb/examples/assignees{/user}
#     - branches_url: https://api.github.com/repos/wandb/examples/branches{/branch}
#     - tags_url: https://api.github.com/repos/wandb/examples/tags
#     - blobs_url: https://api.github.com/repos/wandb/examples/git/blobs{/sha}
#     - git_tags_url: https://api.github.com/repos/wandb/examples/git/tags{/sha}
#     - git_refs_url: https://api.github.com/repos/wandb/examples/git/refs{/sha}
#     - trees_url: https://api.github.com/repos/wandb/examples/git/trees{/sha}
#     - statuses_url: https://api.github.com/repos/wandb/examples/statuses/{sha}
#     - languages_url: https://api.github.com/repos/wandb/examples/languages
#     - stargazers_url: https://api.github.com/repos/wandb/examples/stargazers
#     - contributors_url: https://api.github.com/repos/wandb/examples/contributors
#     - subscribers_url: https://api.github.com/repos/wandb/examples/subscribers
#     - subscription_url: https://api.github.com/repos/wandb/examples/subscription
#     - commits_url: https://api.github.com/repos/wandb/examples/commits{/sha}
#     - git_commits_url: https://api.github.com/repos/wandb/examples/git/commits{/sha}
#     - comments_url: https://api.github.com/repos/wandb/examples/comments{/number}
#     - issue_comment_url: https://api.github.com/repos/wandb/examples/issues/comments{/number}
#     - contents_url: https://api.github.com/repos/wandb/examples/contents/{+path}
#     - compare_url: https://api.github.com/repos/wandb/examples/compare/{base}...{head}
#     - merges_url: https://api.github.com/repos/wandb/examples/merges
#     - archive_url: https://api.github.com/repos/wandb/examples/{archive_format}{/ref}
#     - downloads_url: https://api.github.com/repos/wandb/examples/downloads
#     - issues_url: https://api.github.com/repos/wandb/examples/issues{/number}
#     - pulls_url: https://api.github.com/repos/wandb/examples/pulls{/number}
#     - milestones_url: https://api.github.com/repos/wandb/examples/milestones{/number}
#     - notifications_url: https://api.github.com/repos/wandb/examples/notifications{?since,all,participating}
#     - labels_url: https://api.github.com/repos/wandb/examples/labels{/name}
#     - releases_url: https://api.github.com/repos/wandb/examples/releases{/id}
#     - deployments_url: https://api.github.com/repos/wandb/examples/deployments
#     - created_at: 2018-01-29T17:53:59Z
#     - updated_at: 2022-04-01T13:41:26Z
#     - pushed_at: 2022-04-04T14:31:14Z
#     - git_url: git://github.com/wandb/examples.git
#     - ssh_url: git@github.com:wandb/examples.git
#     - clone_url: https://github.com/wandb/examples.git
#     - svn_url: https://github.com/wandb/examples
#     - homepage: http://wandb.ai
#     - size: 117618
#     - stargazers_count: 664
#     - watchers_count: 664
#     - language: Jupyter Notebook
#     - has_issues: True
#     - has_projects: False
#     - has_downloads: True
#     - has_wiki: True
#     - has_pages: False
#     - forks_count: 206
#     - mirror_url: None
#     - archived: False
#     - disabled: False
#     - open_issues_count: 9
#     - license: None
#     - allow_forking: True
#     - is_template: False
#     - topics:
#
#     - visibility: public
#     - forks: 206
#     - open_issues: 9
#     - watchers: 664
#     - default_branch: master
# - _links:
#   - self:
#     - href: https://api.github.com/repos/wandb/examples/pulls/225
#   - html:
#     - href: https://github.com/wandb/examples/pull/225
#   - issue:
#     - href: https://api.github.com/repos/wandb/examples/issues/225
#   - comments:
#     - href: https://api.github.com/repos/wandb/examples/issues/225/comments
#   - review_comments:
#     - href: https://api.github.com/repos/wandb/examples/pulls/225/comments
#   - review_comment:
#     - href: https://api.github.com/repos/wandb/examples/pulls/comments{/number}
#   - commits:
#     - href: https://api.github.com/repos/wandb/examples/pulls/225/commits
#   - statuses:
#     - href: https://api.github.com/repos/wandb/examples/statuses/e05578363b4ae1fb7c3e8bfd005facd510d8eef3
# - author_association: MEMBER
# - auto_merge: None
# - active_lock_reason: None
# - merged: False
# - mergeable: True
# - rebaseable: True
# - mergeable_state: unstable
# - merged_by: None
# - comments: 3
# - review_comments: 0
# - maintainer_can_modify: True
# - commits: 2
# - additions: 2101
# - deletions: 0
# - changed_files: 2

# %%
head_github_repo = pr.head.repo.full_name
head_branch = pr.head.ref

base_github_repo = pr.base.repo.full_name
base_branch = pr.base.repo.full_name

pr_files = [Path(f.filename) for f in api.pulls.list_files(issue)]

# %%
head_github_repo, base_github_repo
# Out:
# ('ayulockin/examples', 'wandb/examples')

# %%
github_repo
# Out:
# 'ayulockin/examples'

# %%
pr_files
# Out:
# [Path('colabs/pytorch/How_does_adding_dropout_affect_model_performance.ipynb')]

# %%
def _get_colab_url2md(fname: Path, github_repo=github_repo, branch=branch) -> str:
    "Create colab links in md"
    fname = fname.relative_to(git_local_repo(fname))
    colab_url = f"https://colab.research.google.com/github/{github_repo}/blob/{branch}/{str(fname)}"
    return f"- [{fname}]({colab_url})\n"

def _create_comment_body(nb_files) -> str:
    "Creates a MD list of fnames with links to colab"
    title = "The following colabs where changed in this PR:\n"
    colab_links = tuple(_get_colab_url2md(f) for f in nb_files)
    body = tuplify(title) + colab_links
    return "".join(body)

# %%
# filter nbs
nb_files = [f for f in pr_files if is_nb(f)]

# %%
if len(nb_files) > 0:
    body = _create_comment_body(nb_files)
    print(f">> Creating comment on PR #{issue}")
    api.issues.create_comment(issue_number=issue, body=body)
# Out:
# Probably not in a git repo:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sf/tgv7vcv96x557p38bvvp1ms40000gn/T/ipykernel_37251/663663522.py in <module>
#       1 if len(nb_files) > 0:
# ----> 2     body = _create_comment_body(nb_files)
#       3     print(f">> Creating comment on PR #{issue}")
#       4     api.issues.create_comment(issue_number=issue, body=body)
#
# /var/folders/sf/tgv7vcv96x557p38bvvp1ms40000gn/T/ipykernel_37251/2106081609.py in _create_comment_body(nb_files)
#       8     "Creates a MD list of fnames with links to colab"
#       9     title = "The following colabs where changed in this PR:\n"
# ---> 10     colab_links = tuple(_get_colab_url2md(f) for f in nb_files)
#      11     body = tuplify(title) + colab_links
#      12     return "".join(body)
#
# /var/folders/sf/tgv7vcv96x557p38bvvp1ms40000gn/T/ipykernel_37251/2106081609.py in <genexpr>(.0)
#       8     "Creates a MD list of fnames with links to colab"
#       9     title = "The following colabs where changed in this PR:\n"
# ---> 10     colab_links = tuple(_get_colab_url2md(f) for f in nb_files)
#      11     body = tuplify(title) + colab_links
#      12     return "".join(body)
#
# /var/folders/sf/tgv7vcv96x557p38bvvp1ms40000gn/T/ipykernel_37251/2106081609.py in _get_colab_url2md(fname, github_repo, branch)
#       1 def _get_colab_url2md(fname: Path, github_repo=github_repo, branch=branch) -> str:
#       2     "Create colab links in md"
# ----> 3     fname = fname.relative_to(git_local_repo(fname))
#       4     colab_url = f"https://colab.research.google.com/github/{github_repo}/blob/{branch}/{str(fname)}"
#       5     return f"- [{fname}]({colab_url})\n"
#
# ~/miniforge3/envs/nbs/lib/python3.10/pathlib.py in relative_to(self, *other)
#     814         if (root or drv) if n == 0 else cf(abs_parts[:n]) != cf(to_abs_parts):
#     815             formatted = self._format_parsed_parts(to_drv, to_root, to_parts)
# --> 816             raise ValueError("{!r} is not in the subpath of {!r}"
#     817                     " OR one path is relative and the other is absolute."
#     818                              .format(str(self), str(formatted)))
#
# ValueError: 'colabs/pytorch/How_does_adding_dropout_affect_model_performance.ipynb' is not in the subpath of '/Users/tcapelle/wandb/examples/colabs/colabs/pytorch' OR one path is relative and the other is absolute.

# %%
git_local_repo(nb_files[0])
# Out:
# Probably not in a git repo:
# Path('/Users/tcapelle/wandb/examples/colabs/colabs/pytorch')

# %%
print(nb_files[0].absolute())
git_origin_repo(nb_files[0].absolute())
# Out:
# /Users/tcapelle/wandb/examples/colabs/colabs/pytorch/How_does_adding_dropout_affect_model_performance.ipynb
# Probably not in a git repo:
# ''

# %%
git_origin_repo??
# Out:
# Signature: git_origin_repo(fname)
# Source:
# def git_origin_repo(fname):
#     "Get github repo name from `fname`"
#     try:
#         repo_url = run(f"git -C {Path(fname).parent} config --get remote.origin.url")
#
#         # check if ssh or html
#         if "git@" in repo_url:
#             github_repo = re.search(r":(.*?).git", repo_url).group(1)
#         else:
#             github_repo = re.search(r".com/(.*)", repo_url).group(1)
#         return github_repo
#
#     except Exception as e:
#         print(f"Probably not in a git repo: {e}")
#         return ""
# File:      ~/wandb/nb_helpers/nb_helpers/utils.py
# Type:      function
