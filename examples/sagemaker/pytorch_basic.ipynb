# %% [markdown]
# <img src="https://i.imgur.com/gb6B4ig.png" width="400" alt="Weights & Biases" />
#
# <!--- @wandbcode{sagemaker-hf} -->

# %% [markdown]
# # Text Classification with Sagemaker & Weights & Biases
#
# This notebook will demonstrate how to:
# - log the datasets to W&B Tables for EDA
# - train on the [`banking77`](https://huggingface.co/datasets/banking77) dataset
# - train in distributed mode
# - log experiment results to Weights & Biases
# - log the validation predictions to W&B Tables for model evaluation
# - save the model weigths to W&B Artifacts

# %% [markdown]
# ## Sagemaker

# %% [markdown]
# <img src="https://i.imgur.com/Za9P1sr.png" width="400" alt="Weights & Biases" />

# %% [markdown]
# SageMaker is a comprehensive machine learning service. It is a tool that helps data scientists and developers to prepare, build, train, and deploy high-quality machine learning (ML) models by providing a rich set of orchestration tools and features.

# %% [markdown]
# ## Setup

# %%
# !pip install -qqq wandb --upgrade
# !pip install -qq "sagemaker>=2.48.0" "transformers>=4.6.1" "datasets[s3]>=1.6.2" --upgrade

# %% [markdown]
# _If you are going to use Sagemaker in a local environment. You need access to an IAM Role with the required permissions for Sagemaker. You can find [here](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-roles.html) more about it._

# %%
import sagemaker

sess = sagemaker.Session()
# sagemaker session bucket -> used for uploading data, models and logs
# sagemaker will automatically create this bucket if it not exists
sagemaker_session_bucket=None
if sagemaker_session_bucket is None and sess is not None:
    # set to default bucket if a bucket name is not given
    sagemaker_session_bucket = sess.default_bucket()

role = sagemaker.get_execution_role()
sess = sagemaker.Session(default_bucket=sagemaker_session_bucket)

print(f"sagemaker role arn: {role}")
print(f"sagemaker bucket: {sess.default_bucket()}")
print(f"sagemaker session region: {sess.boto_region_name}")
# Out:
# sagemaker role arn: arn:aws:iam::618469898284:role/jeff-sagemaker
# sagemaker bucket: sagemaker-us-east-2-618469898284
# sagemaker session region: us-east-2

# %% [markdown]
# ## Uploading data to `sagemaker_session_bucket`
#
# After we processed the `datasets` we are going to use the new `FileSystem` [integration](https://huggingface.co/docs/datasets/filesystems.html) to upload our dataset to S3.

# %%
import botocore
from datasets.filesystems import S3FileSystem

s3 = S3FileSystem()  

# save train_dataset to s3
training_input_path = f's3://{sess.default_bucket()}/{s3_prefix}/train'
train_dataset.save_to_disk(training_input_path,fs=s3)

# save test_dataset to s3
test_input_path = f's3://{sess.default_bucket()}/{s3_prefix}/test'
test_dataset.save_to_disk(test_input_path,fs=s3)

# %% [markdown]
# # Fine-tuning & starting Sagemaker Training Job
#
# In order to create a sagemaker training job we need an `HuggingFace` Estimator. The Estimator handles end-to-end Amazon SageMaker training and deployment tasks. In a Estimator we define, which fine-tuning script should be used as `entry_point`, which `instance_type` should be used, which `hyperparameters` are passed in .....
#
#
#
# ```python
# huggingface_estimator = HuggingFace(entry_point='train.py',
#                             source_dir='./scripts',
#                             base_job_name='huggingface-sdk-extension',
#                             instance_type='ml.p3.2xlarge',
#                             instance_count=1,
#                             transformers_version='4.4',
#                             pytorch_version='1.6',
#                             py_version='py36',
#                             role=role,
#                             hyperparameters = {'epochs': 1,
#                                                'train_batch_size': 32,
#                                                'model_name':'distilbert-base-uncased'
#                                                 })
# ```
#
# When we create a SageMaker training job, SageMaker takes care of starting and managing all the required ec2 instances for us with the `huggingface` container, uploads the provided fine-tuning script `train.py` and downloads the data from our `sagemaker_session_bucket` into the container at `/opt/ml/input/data`. Then, it starts the training job by running.
#
# ```python
# /opt/conda/bin/python train.py --epochs 1 --model_name distilbert-base-uncased --train_batch_size 32
# ```
#
# The `hyperparameters` you define in the `HuggingFace` estimator are passed in as named arguments.
#
# Sagemaker is providing useful properties about the training environment through various environment variables, including the following:
#
# * `SM_MODEL_DIR`: A string that represents the path where the training job writes the model artifacts to. After training, artifacts in this directory are uploaded to S3 for model hosting.
#
# * `SM_NUM_GPUS`: An integer representing the number of GPUs available to the host.
#
# * `SM_CHANNEL_XXXX:` A string that represents the path to the directory that contains the input data for the specified channel. For example, if you specify two input channels in the HuggingFace estimator’s fit call, named `train` and `test`, the environment variables `SM_CHANNEL_TRAIN` and `SM_CHANNEL_TEST` are set.
#
#
# To run your training job locally you can define `instance_type='local'` or `instance_type='local_gpu'` for gpu usage. _Note: this does not working within SageMaker Studio_

# %%
from datasets import load_dataset
dataset = load_dataset('banking77')

dataset['train'][0]

# dataset['train'].features['label'].names
# Out:
# Using custom data configuration default
# Reusing dataset banking77 (/home/ec2-user/.cache/huggingface/datasets/banking77/default/1.1.0/17ffc2ed47c2ed928bee64127ff1dbc97204cb974c2f980becae7c864007aed9)
# {'label': 11, 'text': 'I am still waiting on my card?'}

# %%
dataset["train"].features["label"][11]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-bb339cea316c> in <module>
# ----> 1 dataset["train"].features["label"][11]
#
# TypeError: 'ClassLabel' object does not support indexing

# %%
label_list = dataset["train"].features["label"].names[:5]
label_list
# Out:
# ['activate_my_card',
#  'age_limit',
#  'apple_pay_or_google_pay',
#  'atm_support',
#  'automatic_top_up']

# %%
label_list.sort()  # Let's sort it for determinism
# num_labels = len(label_list)
label_list
# Out:
# ['activate_my_card',
#  'age_limit',
#  'apple_pay_or_google_pay',
#  'atm_support',
#  'automatic_top_up']

# %%
if is_regression:
    num_labels = 1
else:
    # A useful fast method:
    # https://huggingface.co/docs/datasets/package_reference/main_classes.html#datasets.Dataset.unique
    label_list = raw_datasets["train"].unique("label")
    label_list.sort()  # Let's sort it for determinism
    num_labels = len(label_list)

# %%
eval_dataset = dataset['test']
tokenizer = AutoTokenizer.from_pretrained('distilbert-base-uncased')
eval_dataset = eval_dataset.map(lambda x: tokenizer(x['text'], truncation=True), batched=True)

eval_dataset
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# Dataset({
#     features: ['attention_mask', 'input_ids', 'label', 'text'],
#     num_rows: 3080
# })

# %%
validation_targets = eval_dataset['label']
# convert labels to their respective class
validation_targets = [eval_dataset.features['label'].int2str(x) for x in validation_targets]
validation_targets[:10]
# Out:
# ['card_arrival',
#  'card_arrival',
#  'card_arrival',
#  'card_arrival',
#  'card_arrival',
#  'card_arrival',
#  'card_arrival',
#  'card_arrival',
#  'card_arrival',
#  'card_arrival']

# %%
validation_inputs = eval_dataset.remove_columns(['label', 'attention_mask', 'input_ids'])

validation_targets = eval_dataset['label']
# convert labels to their respective class
validation_targets = [eval_dataset.features['label'].int2str(x) for x in validation_targets]

from wandb.sdk.integration_utils.data_logging import ValidationDataLogger

validation_logger = ValidationDataLogger(
    inputs = validation_inputs[:],
    targets = validation_targets
)
# Out:
# (OrderedDict([('text',
#                ['How do I locate my card?',
#                 'I still have not received my new card, I ordered over a week ago.',
#                 'I ordered a card but it has not arrived. Help please!',
#                 'Is there a way to know when my card will arrive?',
#                 'My card has not arrived yet.',
#                 'When will I get my card?',
#                 'Do you know if there is a tracking number for the new card you sent me?',
#                 'i have not received my card',
#                 'still waiting on that card',
#                 'Is it normal to have to wait over a week for my new card?'])]),
#  ['card_arrival',
#   'card_arrival',
#   'card_arrival',
#   'card_arrival',
#   'card_arrival',
#   'card_arrival',
#   'card_arrival',
#   'card_arrival',
#   'card_arrival',
#   'card_arrival'])

# %%
# from transformers import EvalPrediction
# from typing import Callable

# class ComputeMetrics:
#     def __init__(self, train_len, eval_steps):
#         self.train_len = train_len
#         self.eval_steps = eval_steps
#         self.eval_step_count = eval_steps
        
#     def __call__(self, p: EvalPrediction):
#             preds = p.predictions[0] if isinstance(p.predictions, tuple) else p.predictions
#             preds = np.squeeze(preds) if is_regression else np.argmax(preds, axis=1)

#     #         # ✍️ log predictions to W&B Validation Logger ✍️ 
#     #         preds_labels = [model.config.id2label[x.item()] for x in preds] # convert id to class, (0, 1, 2…) to label (Health, Science…)
#     #         validation_logger.log_predictions(preds_labels)

#             # Create W&B Table
#             validation_table = wandb.Table(columns=['id', 'step', 'pred_label_id'])
#             for i,p in enumerate(preds):
#                 idx = i + len(train_dataset)
#                 row = [idx, self.eval_step_count, p]                    
#                 validation_table.add_data(*row)

#             # Log the table to Weights & Biases
#             wandb.log(
#                 {f'Eval Predictions/{data_args.dataset_name}_{self.eval_step_count}' : validation_table}, 
#                 commit=False
#             )
            
#             self.eval_step_count+=self.eval_steps
            
#             return {"accuracy": (preds == p.label_ids).astype(np.float32).mean().item()}
        
# compute_metrics = ComputeMetrics(100, 100)
# Out:
# True

# %% [markdown]
# ## Creating an Estimator and start a training job

# %%
import wandb
wandb.login()
wandb.sagemaker_auth(path="scripts")

# %%
from sagemaker.huggingface import HuggingFace

# hyperparameters, which are passed into the training job
hyperparameters={
    'output_dir': 'tmp',
    'model_name_or_path': 'distilbert-base-uncased',  # microsoft/deberta-base , roberta-base
    'dataset_name': 'banking77',
    'do_train': True,
    'do_eval': True,
    'per_device_train_batch_size': 64,
    'per_device_eval_batch_size': 64,
    'learning_rate': 1e-4,
    'warmup_steps': 100,
    'fp16': True,
    'logging_steps': 10,
    'max_steps': 1000,
    'eval_steps': 100,
    'save_steps': 200,
    'evaluation_strategy' : 'steps',
    'load_best_model_at_end': True,
    'metric_for_best_model': 'accuracy',
    'report_to': 'wandb',    # ✍️
    'run_name': 'distilbert'    # ✍️
}

# %%
huggingface_estimator = HuggingFace(entry_point='run_text_classification.py',
                            source_dir='./scripts',
                            instance_type= 'ml.p3.2xlarge', #'ml.p3.8xlarge', #'g4dn.12xlarge',
                            instance_count=1,
                            role=role,
                            transformers_version='4.6',
                            pytorch_version='1.7',
                            py_version='py36',
                            hyperparameters = hyperparameters)

# %%
huggingface_estimator.fit()
# Out:
# 2021-08-11 15:30:45 Starting - Starting the training job...ProfilerReport-1628695845: InProgress
# ...
# 2021-08-11 15:31:33 Starting - Launching requested ML instances......
# 2021-08-11 15:32:39 Starting - Preparing the instances for training.........
# 2021-08-11 15:34:15 Downloading - Downloading input data
# 2021-08-11 15:34:15 Training - Downloading the training image.................bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-08-11 15:36:53,898 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-08-11 15:36:53,921 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-08-11 15:36:53,928 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-08-11 15:36:54,255 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /opt/conda/bin/python3.6 -m pip install -r requirements.txt
# Collecting git+https://github.com/huggingface/transformers.git (from -r requirements.txt (line 1))
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-lo6xa4ic
#   Installing build dependencies: started
#
# 2021-08-11 15:37:15 Training - Training image download completed. Training in progress.  Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting datasets>=1.11.0
#   Downloading datasets-1.11.0-py3-none-any.whl (264 kB)
# Collecting wandb>=0.11.2
#   Downloading wandb-0.12.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.6/site-packages (from transformers==4.10.0.dev0->-r requirements.txt (line 1)) (4.49.0)
# Requirement already satisfied: sacremoses in /opt/conda/lib/python3.6/site-packages (from transformers==4.10.0.dev0->-r requirements.txt (line 1)) (0.0.45)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.6/site-packages (from transformers==4.10.0.dev0->-r requirements.txt (line 1)) (0.8)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.6/site-packages (from transformers==4.10.0.dev0->-r requirements.txt (line 1)) (5.4.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.6/site-packages (from transformers==4.10.0.dev0->-r requirements.txt (line 1)) (20.9)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.6/site-packages (from transformers==4.10.0.dev0->-r requirements.txt (line 1)) (3.0.12)
# Collecting huggingface-hub>=0.0.12
#   Downloading huggingface_hub-0.0.15-py3-none-any.whl (43 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from transformers==4.10.0.dev0->-r requirements.txt (line 1)) (2.25.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /opt/conda/lib/python3.6/site-packages (from transformers==4.10.0.dev0->-r requirements.txt (line 1)) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.6/site-packages (from transformers==4.10.0.dev0->-r requirements.txt (line 1)) (2021.4.4)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.6/site-packages (from transformers==4.10.0.dev0->-r requirements.txt (line 1)) (4.0.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.6/site-packages (from transformers==4.10.0.dev0->-r requirements.txt (line 1)) (1.19.1)
# Collecting pyarrow!=4.0.0,>=1.0.0
#   Downloading pyarrow-5.0.0-cp36-cp36m-manylinux2014_x86_64.whl (23.6 MB)
# Requirement already satisfied: dill in /opt/conda/lib/python3.6/site-packages (from datasets>=1.11.0->-r requirements.txt (line 2)) (0.3.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.6/site-packages (from datasets>=1.11.0->-r requirements.txt (line 2)) (1.1.5)
# Requirement already satisfied: fsspec>=2021.05.0 in /opt/conda/lib/python3.6/site-packages (from datasets>=1.11.0->-r requirements.txt (line 2)) (2021.5.0)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.6/site-packages (from datasets>=1.11.0->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.6/site-packages (from datasets>=1.11.0->-r requirements.txt (line 2)) (0.70.11.1)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.18-py3-none-any.whl (170 kB)
# Collecting promise<3,>=2.0
#   Downloading promise-2.3.tar.gz (19 kB)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.6/site-packages (from wandb>=0.11.2->-r requirements.txt (line 3)) (5.8.0)
# Requirement already satisfied: six>=1.13.0 in /opt/conda/lib/python3.6/site-packages (from wandb>=0.11.2->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /opt/conda/lib/python3.6/site-packages (from wandb>=0.11.2->-r requirements.txt (line 3)) (7.1.2)
# Collecting configparser>=3.8.1
#   Downloading configparser-5.0.2-py3-none-any.whl (19 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Collecting subprocess32>=3.5.3
#   Downloading subprocess32-3.5.4.tar.gz (97 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.6/site-packages (from wandb>=0.11.2->-r requirements.txt (line 3)) (2.8.1)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.3.1-py2.py3-none-any.whl (133 kB)
# Requirement already satisfied: protobuf>=3.12.0 in /opt/conda/lib/python3.6/site-packages (from wandb>=0.11.2->-r requirements.txt (line 3)) (3.17.1)
# Requirement already satisfied: typing-extensions>=3.7.4.0 in /opt/conda/lib/python3.6/site-packages (from GitPython>=1.0.0->wandb>=0.11.2->-r requirements.txt (line 3)) (3.10.0.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.6/site-packages (from packaging->transformers==4.10.0.dev0->-r requirements.txt (line 1)) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.10.0.dev0->-r requirements.txt (line 1)) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.10.0.dev0->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.10.0.dev0->-r requirements.txt (line 1)) (1.25.11)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->transformers==4.10.0.dev0->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.6/site-packages (from importlib-metadata->transformers==4.10.0.dev0->-r requirements.txt (line 1)) (3.4.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas->datasets>=1.11.0->-r requirements.txt (line 2)) (2021.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.6/site-packages (from sacremoses->transformers==4.10.0.dev0->-r requirements.txt (line 1)) (1.0.1)
# Building wheels for collected packages: transformers, promise, subprocess32, pathtools
#   Building wheel for transformers (PEP 517): started
#   Building wheel for transformers (PEP 517): finished with status 'done'
#   Created wheel for transformers: filename=transformers-4.10.0.dev0-py3-none-any.whl size=2633849 sha256=d2d3c0508fe0bc9c10ce814ab62f015ad168de1f473eeff1d4fd353bbf024a58
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xf_kfczd/wheels/83/0d/25/e0bd4216d0278109b70f8a6ada5ea35eebbad3de134e416ba3
#   Building wheel for promise (setup.py): started
#   Building wheel for promise (setup.py): finished with status 'done'
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21494 sha256=70f2fb13b68651c20d8ce98e60a1bb621f222f950a1781e67a4fd98ee73e8567
#   Stored in directory: /root/.cache/pip/wheels/59/9a/1d/3f1afbbb5122d0410547bf9eb50955f4a7a98e53a6d8b99bd1
#   Building wheel for subprocess32 (setup.py): started
#   Building wheel for subprocess32 (setup.py): finished with status 'done'
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6487 sha256=57ed0274d26918f541032a429e1cac11d89e0f87781250651ef2e8e349fbf158
#   Stored in directory: /root/.cache/pip/wheels/44/3a/ab/102386d84fe551b6cedb628ed1e74c5f5be76af8b909aeda09
#   Building wheel for pathtools (setup.py): started
#   Building wheel for pathtools (setup.py): finished with status 'done'
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8785 sha256=093fe15acb5f37eb5afe2858d3537037a76593230810363605c6061ee0f2c0e3
#   Stored in directory: /root/.cache/pip/wheels/42/ea/90/e37d463fb3b03848bf715080595de62545266f53dd546b2497
# Successfully built transformers promise subprocess32 pathtools
# Installing collected packages: smmap, gitdb, subprocess32, shortuuid, sentry-sdk, pyarrow, promise, pathtools, huggingface-hub, GitPython, docker-pycreds, configparser, wandb, transformers, datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 4.0.0
#     Uninstalling pyarrow-4.0.0:
#       Successfully uninstalled pyarrow-4.0.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.0.8
#     Uninstalling huggingface-hub-0.0.8:
#       Successfully uninstalled huggingface-hub-0.0.8
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.6.1
#     Uninstalling transformers-4.6.1:
#       Successfully uninstalled transformers-4.6.1
#   Attempting uninstall: datasets
#     Found existing installation: datasets 1.6.2
#     Uninstalling datasets-1.6.2:
#       Successfully uninstalled datasets-1.6.2
# Successfully installed GitPython-3.1.18 configparser-5.0.2 datasets-1.11.0 docker-pycreds-0.4.0 gitdb-4.0.7 huggingface-hub-0.0.15 pathtools-0.1.2 promise-2.3 pyarrow-5.0.0 sentry-sdk-1.3.1 shortuuid-1.0.1 smmap-4.0.0 subprocess32-3.5.4 transformers-4.10.0.dev0 wandb-0.12.0
#   Running command git clone -q https://github.com/huggingface/transformers.git /tmp/pip-req-build-lo6xa4ic
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
#
# 2021-08-11 15:37:18,011 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "evaluation_strategy": "steps",
#         "per_device_eval_batch_size": 64,
#         "load_best_model_at_end": true,
#         "max_steps": 1000,
#         "metric_for_best_model": "accuracy",
#         "do_train": true,
#         "dataset_name": "banking77",
#         "do_eval": true,
#         "warmup_steps": 100,
#         "report_to": "wandb",
#         "save_steps": 200,
#         "output_dir": "tmp",
#         "eval_steps": 100,
#         "per_device_train_batch_size": 64,
#         "run_name": "distilbert",
#         "learning_rate": 0.0001,
#         "logging_steps": 10,
#         "model_name_or_path": "distilbert-base-uncased",
#         "fp16": true
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "huggingface-pytorch-training-2021-08-11-15-30-44-916",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-618469898284/huggingface-pytorch-training-2021-08-11-15-30-44-916/source/sourcedir.tar.gz",
#     "module_name": "run_text_classification",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "run_text_classification.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"dataset_name":"banking77","do_eval":true,"do_train":true,"eval_steps":100,"evaluation_strategy":"steps","fp16":true,"learning_rate":0.0001,"load_best_model_at_end":true,"logging_steps":10,"max_steps":1000,"metric_for_best_model":"accuracy","model_name_or_path":"distilbert-base-uncased","output_dir":"tmp","per_device_eval_batch_size":64,"per_device_train_batch_size":64,"report_to":"wandb","run_name":"distilbert","save_steps":200,"warmup_steps":100}
# SM_USER_ENTRY_POINT=run_text_classification.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=run_text_classification
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-618469898284/huggingface-pytorch-training-2021-08-11-15-30-44-916/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"dataset_name":"banking77","do_eval":true,"do_train":true,"eval_steps":100,"evaluation_strategy":"steps","fp16":true,"learning_rate":0.0001,"load_best_model_at_end":true,"logging_steps":10,"max_steps":1000,"metric_for_best_model":"accuracy","model_name_or_path":"distilbert-base-uncased","output_dir":"tmp","per_device_eval_batch_size":64,"per_device_train_batch_size":64,"report_to":"wandb","run_name":"distilbert","save_steps":200,"warmup_steps":100},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"huggingface-pytorch-training-2021-08-11-15-30-44-916","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-618469898284/huggingface-pytorch-training-2021-08-11-15-30-44-916/source/sourcedir.tar.gz","module_name":"run_text_classification","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"run_text_classification.py"}
# SM_USER_ARGS=["--dataset_name","banking77","--do_eval","True","--do_train","True","--eval_steps","100","--evaluation_strategy","steps","--fp16","True","--learning_rate","0.0001","--load_best_model_at_end","True","--logging_steps","10","--max_steps","1000","--metric_for_best_model","accuracy","--model_name_or_path","distilbert-base-uncased","--output_dir","tmp","--per_device_eval_batch_size","64","--per_device_train_batch_size","64","--report_to","wandb","--run_name","distilbert","--save_steps","200","--warmup_steps","100"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_EVALUATION_STRATEGY=steps
# SM_HP_PER_DEVICE_EVAL_BATCH_SIZE=64
# SM_HP_LOAD_BEST_MODEL_AT_END=true
# SM_HP_MAX_STEPS=1000
# SM_HP_METRIC_FOR_BEST_MODEL=accuracy
# SM_HP_DO_TRAIN=true
# SM_HP_DATASET_NAME=banking77
# SM_HP_DO_EVAL=true
# SM_HP_WARMUP_STEPS=100
# SM_HP_REPORT_TO=wandb
# SM_HP_SAVE_STEPS=200
# SM_HP_OUTPUT_DIR=tmp
# SM_HP_EVAL_STEPS=100
# SM_HP_PER_DEVICE_TRAIN_BATCH_SIZE=64
# SM_HP_RUN_NAME=distilbert
# SM_HP_LEARNING_RATE=0.0001
# SM_HP_LOGGING_STEPS=10
# SM_HP_MODEL_NAME_OR_PATH=distilbert-base-uncased
# SM_HP_FP16=true
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 run_text_classification.py --dataset_name banking77 --do_eval True --do_train True --eval_steps 100 --evaluation_strategy steps --fp16 True --learning_rate 0.0001 --load_best_model_at_end True --logging_steps 10 --max_steps 1000 --metric_for_best_model accuracy --model_name_or_path distilbert-base-uncased --output_dir tmp --per_device_eval_batch_size 64 --per_device_train_batch_size 64 --report_to wandb --run_name distilbert --save_steps 200 --warmup_steps 100
#
#
# 08/11/2021 15:37:25 - WARNING - __main__ - Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: True#015
# 08/11/2021 15:37:25 - INFO - __main__ - Training/evaluation parameters TrainingArguments(#015
# _n_gpu=1,#015
# adafactor=False,#015
# adam_beta1=0.9,#015
# adam_beta2=0.999,#015
# adam_epsilon=1e-08,#015
# dataloader_drop_last=False,#015
# dataloader_num_workers=0,#015
# dataloader_pin_memory=True,#015
# ddp_find_unused_parameters=None,#015
# debug=[],#015
# deepspeed=None,#015
# disable_tqdm=False,#015
# do_eval=True,#015
# do_predict=False,#015
# do_train=True,#015
# eval_accumulation_steps=None,#015
# eval_steps=100,#015
# evaluation_strategy=IntervalStrategy.STEPS,#015
# fp16=True,#015
# fp16_backend=auto,#015
# fp16_full_eval=False,#015
# fp16_opt_level=O1,#015
# gradient_accumulation_steps=1,#015
# greater_is_better=True,#015
# group_by_length=False,#015
# ignore_data_skip=False,#015
# label_names=None,#015
# label_smoothing_factor=0.0,#015
# learning_rate=0.0001,#015
# length_column_name=length,#015
# load_best_model_at_end=True,#015
# local_rank=-1,#015
# log_level=-1,#015
# log_level_replica=-1,#015
# log_on_each_node=True,#015
# logging_dir=tmp/runs/Aug11_15-37-22_algo-1,#015
# logging_first_step=False,#015
# logging_steps=10,#015
# logging_strategy=IntervalStrategy.STEPS,#015
# lr_scheduler_type=SchedulerType.LINEAR,#015
# max_grad_norm=1.0,#015
# max_steps=1000,#015
# metric_for_best_model=accuracy,#015
# mp_parameters=,#015
# no_cuda=False,#015
# num_train_epochs=3.0,#015
# output_dir=tmp,#015
# overwrite_output_dir=False,#015
# past_index=-1,#015
# per_device_eval_batch_size=64,#015
# per_device_train_batch_size=64,#015
# prediction_loss_only=False,#015
# push_to_hub=False,#015
# push_to_hub_model_id=tmp,#015
# push_to_hub_organization=None,#015
# push_to_hub_token=None,#015
# remove_unused_columns=True,#015
# report_to=['wandb'],#015
# resume_from_checkpoint=None,#015
# run_name=distilbert,#015
# save_on_each_node=False,#015
# save_steps=200,#015
# save_strategy=IntervalStrategy.STEPS,#015
# save_total_limit=None,#015
# seed=42,#015
# sharded_ddp=[],#015
# skip_memory_metrics=True,#015
# tpu_metrics_debug=False,#015
# tpu_num_cores=None,#015
# use_legacy_prediction_loop=False,#015
# warmup_ratio=0.0,#015
# warmup_steps=100,#015
# weight_decay=0.0,#015
# )#015
# 08/11/2021 15:37:25 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/huggingface/datasets/1.11.0/datasets/banking77/banking77.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpqqp59nfu#015
# 08/11/2021 15:37:25 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/huggingface/datasets/1.11.0/datasets/banking77/banking77.py in cache at /root/.cache/huggingface/datasets/downloads/ffc5f603d9b0dd57ecd43bf1bd5a6c1137e5b97a9f4cb0208b889c6eb880e518.6188529f4dffa93c0487be7e9b8d88a648e8eff6512e10cf8ae3a7ec01a82b9a.py#015
# 08/11/2021 15:37:25 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/ffc5f603d9b0dd57ecd43bf1bd5a6c1137e5b97a9f4cb0208b889c6eb880e518.6188529f4dffa93c0487be7e9b8d88a648e8eff6512e10cf8ae3a7ec01a82b9a.py#015
# 08/11/2021 15:37:25 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/huggingface/datasets/1.11.0/datasets/banking77/dataset_infos.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpk_w3shkd#015
# 08/11/2021 15:37:25 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/huggingface/datasets/1.11.0/datasets/banking77/dataset_infos.json in cache at /root/.cache/huggingface/datasets/downloads/fa37c8b1b9fdf0554c535caf1e7480906b9110646e6d369182f198d03e7c34db.0bdae177fb52017f87dbdaf681759f2369b91b1e00d0392616cabf4a5f6658ca#015
# 08/11/2021 15:37:25 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/fa37c8b1b9fdf0554c535caf1e7480906b9110646e6d369182f198d03e7c34db.0bdae177fb52017f87dbdaf681759f2369b91b1e00d0392616cabf4a5f6658ca#015
# 08/11/2021 15:37:25 - INFO - datasets.load - Creating main folder for dataset https://raw.githubusercontent.com/huggingface/datasets/1.11.0/datasets/banking77/banking77.py at /root/.cache/huggingface/modules/datasets_modules/datasets/banking77#015
# 08/11/2021 15:37:25 - INFO - datasets.load - Creating specific version folder for dataset https://raw.githubusercontent.com/huggingface/datasets/1.11.0/datasets/banking77/banking77.py at /root/.cache/huggingface/modules/datasets_modules/datasets/banking77/aec0289529599d4572d76ab00c8944cb84f88410ad0c9e7da26189d31f62a55b#015
# 08/11/2021 15:37:25 - INFO - datasets.load - Copying script file from https://raw.githubusercontent.com/huggingface/datasets/1.11.0/datasets/banking77/banking77.py to /root/.cache/huggingface/modules/datasets_modules/datasets/banking77/aec0289529599d4572d76ab00c8944cb84f88410ad0c9e7da26189d31f62a55b/banking77.py#015
# 08/11/2021 15:37:25 - INFO - datasets.load - Copying dataset infos file from https://raw.githubusercontent.com/huggingface/datasets/1.11.0/datasets/banking77/dataset_infos.json to /root/.cache/huggingface/modules/datasets_modules/datasets/banking77/aec0289529599d4572d76ab00c8944cb84f88410ad0c9e7da26189d31f62a55b/dataset_infos.json#015
# 08/11/2021 15:37:25 - INFO - datasets.load - Creating metadata file for dataset https://raw.githubusercontent.com/huggingface/datasets/1.11.0/datasets/banking77/banking77.py at /root/.cache/huggingface/modules/datasets_modules/datasets/banking77/aec0289529599d4572d76ab00c8944cb84f88410ad0c9e7da26189d31f62a55b/banking77.json#015
# 08/11/2021 15:37:25 - WARNING - datasets.builder - Using custom data configuration default#015
# 08/11/2021 15:37:25 - INFO - datasets.info - Loading Dataset Infos from /root/.cache/huggingface/modules/datasets_modules/datasets/banking77/aec0289529599d4572d76ab00c8944cb84f88410ad0c9e7da26189d31f62a55b#015
# 08/11/2021 15:37:25 - INFO - datasets.builder - Generating dataset banking77 (/root/.cache/huggingface/datasets/banking77/default/1.1.0/aec0289529599d4572d76ab00c8944cb84f88410ad0c9e7da26189d31f62a55b)#015
# Downloading and preparing dataset banking77/default (download: 1.03 MiB, generated: 897.51 KiB, post-processed: Unknown size, total: 1.91 MiB) to /root/.cache/huggingface/datasets/banking77/default/1.1.0/aec0289529599d4572d76ab00c8944cb84f88410ad0c9e7da26189d31f62a55b...#015
# 08/11/2021 15:37:25 - INFO - datasets.builder - Dataset not on Hf google storage. Downloading and preparing it from source#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/PolyAI-LDN/task-specific-datasets/master/banking_data/train.csv not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpt0kzj3my#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/PolyAI-LDN/task-specific-datasets/master/banking_data/train.csv in cache at /root/.cache/huggingface/datasets/downloads/bc5a3d80c133c109ecaffda500a00cd8dc8af9bf734036bff41520f5ffdbc23b#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/bc5a3d80c133c109ecaffda500a00cd8dc8af9bf734036bff41520f5ffdbc23b#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.download_manager - Downloading took 0.0 min#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.download_manager - Checksum Computation took 0.0 min#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/PolyAI-LDN/task-specific-datasets/master/banking_data/test.csv not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpaoqopp7x#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/PolyAI-LDN/task-specific-datasets/master/banking_data/test.csv in cache at /root/.cache/huggingface/datasets/downloads/4d2945a4325688f0222a55e1f815b923080633734cc4b1606318611338ff5043#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/4d2945a4325688f0222a55e1f815b923080633734cc4b1606318611338ff5043#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.download_manager - Downloading took 0.0 min#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.download_manager - Checksum Computation took 0.0 min#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.info_utils - All the checksums matched successfully for dataset source files#015
# 08/11/2021 15:37:26 - INFO - datasets.builder - Generating split train#015
# 08/11/2021 15:37:26 - INFO - datasets.builder - Generating split test#015
# 08/11/2021 15:37:26 - INFO - datasets.utils.info_utils - All the splits matched successfully.#015
# Dataset banking77 downloaded and prepared to /root/.cache/huggingface/datasets/banking77/default/1.1.0/aec0289529599d4572d76ab00c8944cb84f88410ad0c9e7da26189d31f62a55b. Subsequent calls will reuse this data.#015
# [INFO|file_utils.py:1632] 2021-08-11 15:37:27,068 >> https://huggingface.co/distilbert-base-uncased/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp54pkc02k#015
# [INFO|file_utils.py:1636] 2021-08-11 15:37:27,133 >> storing https://huggingface.co/distilbert-base-uncased/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361#015
# [INFO|file_utils.py:1644] 2021-08-11 15:37:27,134 >> creating metadata file for /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361#015
# [INFO|configuration_utils.py:545] 2021-08-11 15:37:27,134 >> loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361#015
# [INFO|configuration_utils.py:581] 2021-08-11 15:37:27,136 >> Model config DistilBertConfig {#015
#   "activation": "gelu",#015
#   "architectures": [#015
#     "DistilBertForMaskedLM"#015
#   ],#015
#   "attention_dropout": 0.1,#015
#   "dim": 768,#015
#   "dropout": 0.1,#015
#   "hidden_dim": 3072,#015
#   "id2label": {#015
#     "0": "LABEL_0",#015
#     "1": "LABEL_1",#015
#     "2": "LABEL_2",#015
#     "3": "LABEL_3",#015
#     "4": "LABEL_4",#015
#     "5": "LABEL_5",#015
#     "6": "LABEL_6",#015
#     "7": "LABEL_7",#015
#     "8": "LABEL_8",#015
#     "9": "LABEL_9",#015
#     "10": "LABEL_10",#015
#     "11": "LABEL_11",#015
#     "12": "LABEL_12",#015
#     "13": "LABEL_13",#015
#     "14": "LABEL_14",#015
#     "15": "LABEL_15",#015
#     "16": "LABEL_16",#015
#     "17": "LABEL_17",#015
#     "18": "LABEL_18",#015
#     "19": "LABEL_19",#015
#     "20": "LABEL_20",#015
#     "21": "LABEL_21",#015
#     "22": "LABEL_22",#015
#     "23": "LABEL_23",#015
#     "24": "LABEL_24",#015
#     "25": "LABEL_25",#015
#     "26": "LABEL_26",#015
#     "27": "LABEL_27",#015
#     "28": "LABEL_28",#015
#     "29": "LABEL_29",#015
#     "30": "LABEL_30",#015
#     "31": "LABEL_31",#015
#     "32": "LABEL_32",#015
#     "33": "LABEL_33",#015
#     "34": "LABEL_34",#015
#     "35": "LABEL_35",#015
#     "36": "LABEL_36",#015
#     "37": "LABEL_37",#015
#     "38": "LABEL_38",#015
#     "39": "LABEL_39",#015
#     "40": "LABEL_40",#015
#     "41": "LABEL_41",#015
#     "42": "LABEL_42",#015
#     "43": "LABEL_43",#015
#     "44": "LABEL_44",#015
#     "45": "LABEL_45",#015
#     "46": "LABEL_46",#015
#     "47": "LABEL_47",#015
#     "48": "LABEL_48",#015
#     "49": "LABEL_49",#015
#     "50": "LABEL_50",#015
#     "51": "LABEL_51",#015
#     "52": "LABEL_52",#015
#     "53": "LABEL_53",#015
#     "54": "LABEL_54",#015
#     "55": "LABEL_55",#015
#     "56": "LABEL_56",#015
#     "57": "LABEL_57",#015
#     "58": "LABEL_58",#015
#     "59": "LABEL_59",#015
#     "60": "LABEL_60",#015
#     "61": "LABEL_61",#015
#     "62": "LABEL_62",#015
#     "63": "LABEL_63",#015
#     "64": "LABEL_64",#015
#     "65": "LABEL_65",#015
#     "66": "LABEL_66",#015
#     "67": "LABEL_67",#015
#     "68": "LABEL_68",#015
#     "69": "LABEL_69",#015
#     "70": "LABEL_70",#015
#     "71": "LABEL_71",#015
#     "72": "LABEL_72",#015
#     "73": "LABEL_73",#015
#     "74": "LABEL_74",#015
#     "75": "LABEL_75",#015
#     "76": "LABEL_76"#015
#   },#015
#   "initializer_range": 0.02,#015
#   "label2id": {#015
#     "LABEL_0": 0,#015
#     "LABEL_1": 1,#015
#     "LABEL_10": 10,#015
#     "LABEL_11": 11,#015
#     "LABEL_12": 12,#015
#     "LABEL_13": 13,#015
#     "LABEL_14": 14,#015
#     "LABEL_15": 15,#015
#     "LABEL_16": 16,#015
#     "LABEL_17": 17,#015
#     "LABEL_18": 18,#015
#     "LABEL_19": 19,#015
#     "LABEL_2": 2,#015
#     "LABEL_20": 20,#015
#     "LABEL_21": 21,#015
#     "LABEL_22": 22,#015
#     "LABEL_23": 23,#015
#     "LABEL_24": 24,#015
#     "LABEL_25": 25,#015
#     "LABEL_26": 26,#015
#     "LABEL_27": 27,#015
#     "LABEL_28": 28,#015
#     "LABEL_29": 29,#015
#     "LABEL_3": 3,#015
#     "LABEL_30": 30,#015
#     "LABEL_31": 31,#015
#     "LABEL_32": 32,#015
#     "LABEL_33": 33,#015
#     "LABEL_34": 34,#015
#     "LABEL_35": 35,#015
#     "LABEL_36": 36,#015
#     "LABEL_37": 37,#015
#     "LABEL_38": 38,#015
#     "LABEL_39": 39,#015
#     "LABEL_4": 4,#015
#     "LABEL_40": 40,#015
#     "LABEL_41": 41,#015
#     "LABEL_42": 42,#015
#     "LABEL_43": 43,#015
#     "LABEL_44": 44,#015
#     "LABEL_45": 45,#015
#     "LABEL_46": 46,#015
#     "LABEL_47": 47,#015
#     "LABEL_48": 48,#015
#     "LABEL_49": 49,#015
#     "LABEL_5": 5,#015
#     "LABEL_50": 50,#015
#     "LABEL_51": 51,#015
#     "LABEL_52": 52,#015
#     "LABEL_53": 53,#015
#     "LABEL_54": 54,#015
#     "LABEL_55": 55,#015
#     "LABEL_56": 56,#015
#     "LABEL_57": 57,#015
#     "LABEL_58": 58,#015
#     "LABEL_59": 59,#015
#     "LABEL_6": 6,#015
#     "LABEL_60": 60,#015
#     "LABEL_61": 61,#015
#     "LABEL_62": 62,#015
#     "LABEL_63": 63,#015
#     "LABEL_64": 64,#015
#     "LABEL_65": 65,#015
#     "LABEL_66": 66,#015
#     "LABEL_67": 67,#015
#     "LABEL_68": 68,#015
#     "LABEL_69": 69,#015
#     "LABEL_7": 7,#015
#     "LABEL_70": 70,#015
#     "LABEL_71": 71,#015
#     "LABEL_72": 72,#015
#     "LABEL_73": 73,#015
#     "LABEL_74": 74,#015
#     "LABEL_75": 75,#015
#     "LABEL_76": 76,#015
#     "LABEL_8": 8,#015
#     "LABEL_9": 9#015
#   },#015
#   "max_position_embeddings": 512,#015
#   "model_type": "distilbert",#015
#   "n_heads": 12,#015
#   "n_layers": 6,#015
#   "pad_token_id": 0,#015
#   "qa_dropout": 0.1,#015
#   "seq_classif_dropout": 0.2,#015
#   "sinusoidal_pos_embds": false,#015
#   "tie_weights_": true,#015
#   "transformers_version": "4.10.0.dev0",#015
#   "vocab_size": 30522#015
# }#015
# #015
# [INFO|file_utils.py:1632] 2021-08-11 15:37:27,207 >> https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpz1y42bbi#015
# [INFO|file_utils.py:1636] 2021-08-11 15:37:27,309 >> storing https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/8c8624b8ac8aa99c60c912161f8332de003484428c47906d7ff7eb7f73eecdbb.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79#015
# [INFO|file_utils.py:1644] 2021-08-11 15:37:27,309 >> creating metadata file for /root/.cache/huggingface/transformers/8c8624b8ac8aa99c60c912161f8332de003484428c47906d7ff7eb7f73eecdbb.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79#015
# [INFO|configuration_utils.py:545] 2021-08-11 15:37:27,373 >> loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361#015
# [INFO|configuration_utils.py:581] 2021-08-11 15:37:27,374 >> Model config DistilBertConfig {#015
#   "activation": "gelu",#015
#   "architectures": [#015
#     "DistilBertForMaskedLM"#015
#   ],#015
#   "attention_dropout": 0.1,#015
#   "dim": 768,#015
#   "dropout": 0.1,#015
#   "hidden_dim": 3072,#015
#   "initializer_range": 0.02,#015
#   "max_position_embeddings": 512,#015
#   "model_type": "distilbert",#015
#   "n_heads": 12,#015
#   "n_layers": 6,#015
#   "pad_token_id": 0,#015
#   "qa_dropout": 0.1,#015
#   "seq_classif_dropout": 0.2,#015
#   "sinusoidal_pos_embds": false,#015
#   "tie_weights_": true,#015
#   "transformers_version": "4.10.0.dev0",#015
#   "vocab_size": 30522#015
# }#015
# #015
# [INFO|file_utils.py:1632] 2021-08-11 15:37:27,501 >> https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpeulwbbx6#015
# [INFO|file_utils.py:1636] 2021-08-11 15:37:27,593 >> storing https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt in cache at /root/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99#015
# [INFO|file_utils.py:1644] 2021-08-11 15:37:27,594 >> creating metadata file for /root/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99#015
# [INFO|file_utils.py:1632] 2021-08-11 15:37:27,656 >> https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmp922yp13p#015
# [INFO|file_utils.py:1636] 2021-08-11 15:37:27,756 >> storing https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer.json in cache at /root/.cache/huggingface/transformers/75abb59d7a06f4f640158a9bfcde005264e59e8d566781ab1415b139d2e4c603.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4#015
# [INFO|file_utils.py:1644] 2021-08-11 15:37:27,756 >> creating metadata file for /root/.cache/huggingface/transformers/75abb59d7a06f4f640158a9bfcde005264e59e8d566781ab1415b139d2e4c603.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4#015
# [INFO|tokenization_utils_base.py:1730] 2021-08-11 15:37:27,966 >> loading file https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt from cache at /root/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99#015
# [INFO|tokenization_utils_base.py:1730] 2021-08-11 15:37:27,966 >> loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer.json from cache at /root/.cache/huggingface/transformers/75abb59d7a06f4f640158a9bfcde005264e59e8d566781ab1415b139d2e4c603.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4#015
# [INFO|tokenization_utils_base.py:1730] 2021-08-11 15:37:27,967 >> loading file https://huggingface.co/distilbert-base-uncased/resolve/main/added_tokens.json from cache at None#015
# [INFO|tokenization_utils_base.py:1730] 2021-08-11 15:37:27,967 >> loading file https://huggingface.co/distilbert-base-uncased/resolve/main/special_tokens_map.json from cache at None#015
# [INFO|tokenization_utils_base.py:1730] 2021-08-11 15:37:27,967 >> loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/8c8624b8ac8aa99c60c912161f8332de003484428c47906d7ff7eb7f73eecdbb.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79#015
# [INFO|configuration_utils.py:545] 2021-08-11 15:37:28,032 >> loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.d423bdf2f58dc8b77d5f5d18028d7ae4a72dcfd8f468e81fe979ada957a8c361#015
# [INFO|configuration_utils.py:581] 2021-08-11 15:37:28,032 >> Model config DistilBertConfig {#015
#   "activation": "gelu",#015
#   "architectures": [#015
#     "DistilBertForMaskedLM"#015
#   ],#015
#   "attention_dropout": 0.1,#015
#   "dim": 768,#015
#   "dropout": 0.1,#015
#   "hidden_dim": 3072,#015
#   "initializer_range": 0.02,#015
#   "max_position_embeddings": 512,#015
#   "model_type": "distilbert",#015
#   "n_heads": 12,#015
#   "n_layers": 6,#015
#   "pad_token_id": 0,#015
#   "qa_dropout": 0.1,#015
#   "seq_classif_dropout": 0.2,#015
#   "sinusoidal_pos_embds": false,#015
#   "tie_weights_": true,#015
#   "transformers_version": "4.10.0.dev0",#015
#   "vocab_size": 30522#015
# }#015
# #015
# [INFO|file_utils.py:1632] 2021-08-11 15:37:28,153 >> https://huggingface.co/distilbert-base-uncased/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpehdsgl_h#015
# [INFO|file_utils.py:1636] 2021-08-11 15:37:33,482 >> storing https://huggingface.co/distilbert-base-uncased/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a#015
# [INFO|file_utils.py:1644] 2021-08-11 15:37:33,482 >> creating metadata file for /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a#015
# [INFO|modeling_utils.py:1275] 2021-08-11 15:37:33,482 >> loading weights file https://huggingface.co/distilbert-base-uncased/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a#015
# [WARNING|modeling_utils.py:1512] 2021-08-11 15:37:34,450 >> Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight']#015
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).#015
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).#015
# [WARNING|modeling_utils.py:1523] 2021-08-11 15:37:34,451 >> Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.weight', 'pre_classifier.weight', 'classifier.bias', 'pre_classifier.bias']#015
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.#015
# 08/11/2021 15:37:34 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/banking77/default/1.1.0/aec0289529599d4572d76ab00c8944cb84f88410ad0c9e7da26189d31f62a55b/cache-897402f548f86cf5.arrow#015
# 08/11/2021 15:37:35 - INFO - datasets.arrow_dataset - Caching processed dataset at /root/.cache/huggingface/datasets/banking77/default/1.1.0/aec0289529599d4572d76ab00c8944cb84f88410ad0c9e7da26189d31f62a55b/cache-10fb7038ab5a0b04.arrow#015
# 08/11/2021 15:37:43 - INFO - datasets.utils.file_utils - https://raw.githubusercontent.com/huggingface/datasets/1.11.0/metrics/accuracy/accuracy.py not found in cache or force_download set to True, downloading to /root/.cache/huggingface/datasets/downloads/tmpvj9a0y1j#015
# 08/11/2021 15:37:43 - INFO - datasets.utils.file_utils - storing https://raw.githubusercontent.com/huggingface/datasets/1.11.0/metrics/accuracy/accuracy.py in cache at /root/.cache/huggingface/datasets/downloads/591d385c0492ec80bad3323a081d7b1126c681a389acd9759f0a3098d2034ceb.1d0bd855d8e3c9eb14daa00edb910a511da1d653aeca8e7bc5dffb23a84d7b54.py#015
# 08/11/2021 15:37:43 - INFO - datasets.utils.file_utils - creating metadata file for /root/.cache/huggingface/datasets/downloads/591d385c0492ec80bad3323a081d7b1126c681a389acd9759f0a3098d2034ceb.1d0bd855d8e3c9eb14daa00edb910a511da1d653aeca8e7bc5dffb23a84d7b54.py#015
# 08/11/2021 15:37:43 - INFO - datasets.load - Creating main folder for metric https://raw.githubusercontent.com/huggingface/datasets/1.11.0/metrics/accuracy/accuracy.py at /root/.cache/huggingface/modules/datasets_modules/metrics/accuracy#015
# 08/11/2021 15:37:43 - INFO - datasets.load - Creating specific version folder for metric https://raw.githubusercontent.com/huggingface/datasets/1.11.0/metrics/accuracy/accuracy.py at /root/.cache/huggingface/modules/datasets_modules/metrics/accuracy/6dba4616f6b2bbd19659d1db3a48cc001c8f13a10cdc73a2641a55f7a60b7b5b#015
# 08/11/2021 15:37:43 - INFO - datasets.load - Copying script file from https://raw.githubusercontent.com/huggingface/datasets/1.11.0/metrics/accuracy/accuracy.py to /root/.cache/huggingface/modules/datasets_modules/metrics/accuracy/6dba4616f6b2bbd19659d1db3a48cc001c8f13a10cdc73a2641a55f7a60b7b5b/accuracy.py#015
# 08/11/2021 15:37:43 - INFO - datasets.load - Couldn't find dataset infos file at https://raw.githubusercontent.com/huggingface/datasets/1.11.0/metrics/accuracy/dataset_infos.json#015
# 08/11/2021 15:37:43 - INFO - datasets.load - Creating metadata file for metric https://raw.githubusercontent.com/huggingface/datasets/1.11.0/metrics/accuracy/accuracy.py at /root/.cache/huggingface/modules/datasets_modules/metrics/accuracy/6dba4616f6b2bbd19659d1db3a48cc001c8f13a10cdc73a2641a55f7a60b7b5b/accuracy.json#015
# [INFO|trainer.py:404] 2021-08-11 15:37:46,681 >> max_steps is given, it will override any value given in num_train_epochs#015
# [INFO|trainer.py:421] 2021-08-11 15:37:46,681 >> Using amp fp16 backend#015
# [INFO|trainer.py:528] 2021-08-11 15:37:46,682 >> The following columns in the training set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.#015
# [INFO|trainer.py:1171] 2021-08-11 15:37:46,698 >> ***** Running training *****#015
# [INFO|trainer.py:1172] 2021-08-11 15:37:46,699 >>   Num examples = 10003#015
# [INFO|trainer.py:1173] 2021-08-11 15:37:46,699 >>   Num Epochs = 7#015
# [INFO|trainer.py:1174] 2021-08-11 15:37:46,699 >>   Instantaneous batch size per device = 64#015
# [INFO|trainer.py:1175] 2021-08-11 15:37:46,699 >>   Total train batch size (w. parallel, distributed & accumulation) = 64#015
# [INFO|trainer.py:1176] 2021-08-11 15:37:46,699 >>   Gradient Accumulation steps = 1#015
# [INFO|trainer.py:1177] 2021-08-11 15:37:46,699 >>   Total optimization steps = 1000#015
# [INFO|integrations.py:447] 2021-08-11 15:37:46,701 >> Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"#015
# [2021-08-11 15:37:46.905 algo-1:75 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None#015
# [2021-08-11 15:37:46.975 algo-1:75 INFO profiler_config_parser.py:102] User has disabled profiler.#015
# [2021-08-11 15:37:46.976 algo-1:75 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.#015
# [2021-08-11 15:37:46.976 algo-1:75 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.#015
# [2021-08-11 15:37:46.977 algo-1:75 INFO hook.py:255] Saving to /opt/ml/output/tensors#015
# [2021-08-11 15:37:46.977 algo-1:75 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.#015
# [2021-08-11 15:37:47.136 algo-1:75 INFO hook.py:591] name:distilbert.embeddings.word_embeddings.weight count_params:23440896#015
# [2021-08-11 15:37:47.136 algo-1:75 INFO hook.py:591] name:distilbert.embeddings.position_embeddings.weight count_params:393216#015
# [2021-08-11 15:37:47.136 algo-1:75 INFO hook.py:591] name:distilbert.embeddings.LayerNorm.weight count_params:768#015
# [2021-08-11 15:37:47.136 algo-1:75 INFO hook.py:591] name:distilbert.embeddings.LayerNorm.bias count_params:768#015
# [2021-08-11 15:37:47.136 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.attention.q_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.136 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.attention.q_lin.bias count_params:768#015
# [2021-08-11 15:37:47.136 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.attention.k_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.136 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.attention.k_lin.bias count_params:768#015
# [2021-08-11 15:37:47.137 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.attention.v_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.137 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.attention.v_lin.bias count_params:768#015
# [2021-08-11 15:37:47.137 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.attention.out_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.137 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.attention.out_lin.bias count_params:768#015
# [2021-08-11 15:37:47.137 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.sa_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.137 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.sa_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.137 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.ffn.lin1.weight count_params:2359296#015
# [2021-08-11 15:37:47.137 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.ffn.lin1.bias count_params:3072#015
# [2021-08-11 15:37:47.137 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.ffn.lin2.weight count_params:2359296#015
# [2021-08-11 15:37:47.137 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.ffn.lin2.bias count_params:768#015
# [2021-08-11 15:37:47.138 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.output_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.138 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.0.output_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.138 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.attention.q_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.138 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.attention.q_lin.bias count_params:768#015
# [2021-08-11 15:37:47.138 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.attention.k_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.138 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.attention.k_lin.bias count_params:768#015
# [2021-08-11 15:37:47.138 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.attention.v_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.138 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.attention.v_lin.bias count_params:768#015
# [2021-08-11 15:37:47.138 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.attention.out_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.138 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.attention.out_lin.bias count_params:768#015
# [2021-08-11 15:37:47.138 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.sa_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.139 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.sa_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.139 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.ffn.lin1.weight count_params:2359296#015
# [2021-08-11 15:37:47.139 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.ffn.lin1.bias count_params:3072#015
# [2021-08-11 15:37:47.139 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.ffn.lin2.weight count_params:2359296#015
# [2021-08-11 15:37:47.139 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.ffn.lin2.bias count_params:768#015
# [2021-08-11 15:37:47.139 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.output_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.139 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.1.output_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.139 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.attention.q_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.139 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.attention.q_lin.bias count_params:768#015
# [2021-08-11 15:37:47.139 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.attention.k_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.140 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.attention.k_lin.bias count_params:768#015
# [2021-08-11 15:37:47.140 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.attention.v_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.140 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.attention.v_lin.bias count_params:768#015
# [2021-08-11 15:37:47.140 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.attention.out_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.140 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.attention.out_lin.bias count_params:768#015
# [2021-08-11 15:37:47.140 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.sa_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.140 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.sa_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.140 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.ffn.lin1.weight count_params:2359296#015
# [2021-08-11 15:37:47.140 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.ffn.lin1.bias count_params:3072#015
# [2021-08-11 15:37:47.140 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.ffn.lin2.weight count_params:2359296#015
# [2021-08-11 15:37:47.140 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.ffn.lin2.bias count_params:768#015
# [2021-08-11 15:37:47.141 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.output_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.141 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.2.output_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.141 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.attention.q_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.141 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.attention.q_lin.bias count_params:768#015
# [2021-08-11 15:37:47.141 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.attention.k_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.141 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.attention.k_lin.bias count_params:768#015
# [2021-08-11 15:37:47.141 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.attention.v_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.141 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.attention.v_lin.bias count_params:768#015
# [2021-08-11 15:37:47.141 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.attention.out_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.141 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.attention.out_lin.bias count_params:768#015
# [2021-08-11 15:37:47.142 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.sa_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.142 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.sa_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.142 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.ffn.lin1.weight count_params:2359296#015
# [2021-08-11 15:37:47.142 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.ffn.lin1.bias count_params:3072#015
# [2021-08-11 15:37:47.142 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.ffn.lin2.weight count_params:2359296#015
# [2021-08-11 15:37:47.142 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.ffn.lin2.bias count_params:768#015
# [2021-08-11 15:37:47.142 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.output_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.142 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.3.output_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.142 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.attention.q_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.142 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.attention.q_lin.bias count_params:768#015
# [2021-08-11 15:37:47.143 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.attention.k_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.143 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.attention.k_lin.bias count_params:768#015
# [2021-08-11 15:37:47.143 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.attention.v_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.143 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.attention.v_lin.bias count_params:768#015
# [2021-08-11 15:37:47.143 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.attention.out_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.143 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.attention.out_lin.bias count_params:768#015
# [2021-08-11 15:37:47.143 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.sa_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.143 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.sa_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.143 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.ffn.lin1.weight count_params:2359296#015
# [2021-08-11 15:37:47.143 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.ffn.lin1.bias count_params:3072#015
# [2021-08-11 15:37:47.143 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.ffn.lin2.weight count_params:2359296#015
# [2021-08-11 15:37:47.144 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.ffn.lin2.bias count_params:768#015
# [2021-08-11 15:37:47.144 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.output_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.144 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.4.output_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.144 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.q_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.144 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.q_lin.bias count_params:768#015
# [2021-08-11 15:37:47.144 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.k_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.144 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.k_lin.bias count_params:768#015
# [2021-08-11 15:37:47.144 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.v_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.144 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.v_lin.bias count_params:768#015
# [2021-08-11 15:37:47.144 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.out_lin.weight count_params:589824#015
# [2021-08-11 15:37:47.144 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.attention.out_lin.bias count_params:768#015
# [2021-08-11 15:37:47.145 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.sa_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.145 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.sa_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.145 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.ffn.lin1.weight count_params:2359296#015
# [2021-08-11 15:37:47.145 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.ffn.lin1.bias count_params:3072#015
# [2021-08-11 15:37:47.145 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.ffn.lin2.weight count_params:2359296#015
# [2021-08-11 15:37:47.145 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.ffn.lin2.bias count_params:768#015
# [2021-08-11 15:37:47.145 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.output_layer_norm.weight count_params:768#015
# [2021-08-11 15:37:47.145 algo-1:75 INFO hook.py:591] name:distilbert.transformer.layer.5.output_layer_norm.bias count_params:768#015
# [2021-08-11 15:37:47.145 algo-1:75 INFO hook.py:591] name:pre_classifier.weight count_params:589824#015
# [2021-08-11 15:37:47.145 algo-1:75 INFO hook.py:591] name:pre_classifier.bias count_params:768#015
# [2021-08-11 15:37:47.146 algo-1:75 INFO hook.py:591] name:classifier.weight count_params:59136#015
# [2021-08-11 15:37:47.146 algo-1:75 INFO hook.py:591] name:classifier.bias count_params:77#015
# [2021-08-11 15:37:47.146 algo-1:75 INFO hook.py:593] Total Trainable Params: 67012685#015
# [2021-08-11 15:37:47.146 algo-1:75 INFO hook.py:425] Monitoring the collections: losses#015
# [2021-08-11 15:37:47.149 algo-1:75 INFO hook.py:488] Hook is writing from the hook with pid: 75#015
# #015
# {'loss': 4.3418, 'learning_rate': 1e-05, 'epoch': 0.06}#015
# {'loss': 4.3435, 'learning_rate': 2e-05, 'epoch': 0.13}#015
# {'loss': 4.331, 'learning_rate': 3e-05, 'epoch': 0.19}#015
# {'loss': 4.2921, 'learning_rate': 4e-05, 'epoch': 0.25}#015
# {'loss': 4.2127, 'learning_rate': 5e-05, 'epoch': 0.32}#015
# {'loss': 4.0269, 'learning_rate': 6e-05, 'epoch': 0.38}#015
# {'loss': 3.7924, 'learning_rate': 7e-05, 'epoch': 0.45}#015
# {'loss': 3.5065, 'learning_rate': 8e-05, 'epoch': 0.51}#015
# {'loss': 3.1889, 'learning_rate': 9e-05, 'epoch': 0.57}#015
# {'loss': 2.8425, 'learning_rate': 0.0001, 'epoch': 0.64}#015
# [INFO|trainer.py:528] 2021-08-11 15:38:00,846 >> The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.#015
# [INFO|trainer.py:2174] 2021-08-11 15:38:00,850 >> ***** Running Evaluation *****#015
# [INFO|trainer.py:2176] 2021-08-11 15:38:00,850 >>   Num examples = 3080#015
# [INFO|trainer.py:2179] 2021-08-11 15:38:00,850 >>   Batch size = 64#015
# {'eval_loss': 2.6183829307556152, 'eval_accuracy': 0.5525974035263062, 'eval_runtime': 4.0775, 'eval_samples_per_second': 755.361, 'eval_steps_per_second': 12.017, 'epoch': 0.64}#015
# [INFO|trainer.py:1928] 2021-08-11 15:38:05,320 >> Saving model checkpoint to tmp/checkpoint-100#015
# [INFO|configuration_utils.py:379] 2021-08-11 15:38:05,321 >> Configuration saved in tmp/checkpoint-100/config.json#015
# [INFO|modeling_utils.py:1001] 2021-08-11 15:38:06,011 >> Model weights saved in tmp/checkpoint-100/pytorch_model.bin#015
# [INFO|tokenization_utils_base.py:2003] 2021-08-11 15:38:06,012 >> tokenizer config file saved in tmp/checkpoint-100/tokenizer_config.json#015
# [INFO|tokenization_utils_base.py:2009] 2021-08-11 15:38:06,013 >> Special tokens file saved in tmp/checkpoint-100/special_tokens_map.json#015
# {'loss': 2.4691, 'learning_rate': 9.888888888888889e-05, 'epoch': 0.7}#015
# {'loss': 2.1114, 'learning_rate': 9.777777777777778e-05, 'epoch': 0.76}#015
# {'loss': 1.7806, 'learning_rate': 9.666666666666667e-05, 'epoch': 0.83}#015
# {'loss': 1.6011, 'learning_rate': 9.555555555555557e-05, 'epoch': 0.89}#015
# {'loss': 1.4616, 'learning_rate': 9.444444444444444e-05, 'epoch': 0.96}#015
# {'loss': 1.1977, 'learning_rate': 9.333333333333334e-05, 'epoch': 1.02}#015
# {'loss': 1.0245, 'learning_rate': 9.222222222222223e-05, 'epoch': 1.08}#015
# {'loss': 0.8938, 'learning_rate': 9.111111111111112e-05, 'epoch': 1.15}#015
# {'loss': 0.8272, 'learning_rate': 9e-05, 'epoch': 1.21}#015
# {'loss': 0.7318, 'learning_rate': 8.888888888888889e-05, 'epoch': 1.27}#015
# [INFO|trainer.py:528] 2021-08-11 15:38:19,589 >> The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.#015
# [INFO|trainer.py:2174] 2021-08-11 15:38:19,593 >> ***** Running Evaluation *****#015
# [INFO|trainer.py:2176] 2021-08-11 15:38:19,593 >>   Num examples = 3080#015
# [INFO|trainer.py:2179] 2021-08-11 15:38:19,593 >>   Batch size = 64#015
# {'eval_loss': 0.6985494494438171, 'eval_accuracy': 0.8525974154472351, 'eval_runtime': 3.9904, 'eval_samples_per_second': 771.858, 'eval_steps_per_second': 12.28, 'epoch': 1.27}#015
# [INFO|trainer.py:1928] 2021-08-11 15:38:23,983 >> Saving model checkpoint to tmp/checkpoint-200#015
# [INFO|configuration_utils.py:379] 2021-08-11 15:38:23,985 >> Configuration saved in tmp/checkpoint-200/config.json#015
# [INFO|modeling_utils.py:1001] 2021-08-11 15:38:24,650 >> Model weights saved in tmp/checkpoint-200/pytorch_model.bin#015
# [INFO|tokenization_utils_base.py:2003] 2021-08-11 15:38:24,650 >> tokenizer config file saved in tmp/checkpoint-200/tokenizer_config.json#015
# [INFO|tokenization_utils_base.py:2009] 2021-08-11 15:38:24,651 >> Special tokens file saved in tmp/checkpoint-200/special_tokens_map.json#015
# {'loss': 0.59, 'learning_rate': 8.777777777777778e-05, 'epoch': 1.34}#015
# {'loss': 0.5929, 'learning_rate': 8.666666666666667e-05, 'epoch': 1.4}#015
# {'loss': 0.572, 'learning_rate': 8.555555555555556e-05, 'epoch': 1.46}#015
# {'loss': 0.53, 'learning_rate': 8.444444444444444e-05, 'epoch': 1.53}#015
# {'loss': 0.5083, 'learning_rate': 8.333333333333334e-05, 'epoch': 1.59}#015
# {'loss': 0.4486, 'learning_rate': 8.222222222222222e-05, 'epoch': 1.66}#015
# {'loss': 0.456, 'learning_rate': 8.111111111111112e-05, 'epoch': 1.72}#015
# {'loss': 0.4485, 'learning_rate': 8e-05, 'epoch': 1.78}#015
# {'loss': 0.4734, 'learning_rate': 7.88888888888889e-05, 'epoch': 1.85}#015
# {'loss': 0.4563, 'learning_rate': 7.777777777777778e-05, 'epoch': 1.91}#015
# [INFO|trainer.py:528] 2021-08-11 15:38:38,285 >> The following columns in the evaluation set  don't have a corresponding argument in `DistilBertForSequenceClassification.forward` and have been ignored: text.#015
# [INFO|trainer.py:2174] 2021-08-11 15:38:38,289 >> ***** Running Evaluation *****#015
# [INFO|trainer.py:2176] 2021-08-11 15:38:38,289 >>   Num examples = 3080#015
# [INFO|trainer.py:2179] 2021-08-11 15:38:38,289 >>   Batch size = 64#015

# %%
1

# %% [markdown]
# ### Estimator Parameters

# %%
# container image used for training job
print(f"container image used for training job: \n{huggingface_estimator.image_uri}\n")

# s3 uri where the trained model is located
print(f"s3 uri where the trained model is located: \n{huggingface_estimator.model_data}\n")

# latest training job name for this estimator
print(f"latest training job name for this estimator: \n{huggingface_estimator.latest_training_job.name}\n")
# Out:
# container image used for training job:
# 558105141721.dkr.ecr.us-east-1.amazonaws.com/huggingface-training:pytorch1.6.0-transformers4.2.2-tokenizers0.9.4-datasets1.2.1-py36-gpu-cu110
#
# s3 uri where the trained model is located:
# s3://philipps-sagemaker-bucket-us-east-1/huggingface-training-2021-02-04-16-47-39-189/output/model.tar.gz
#
# latest training job name for this estimator:
# huggingface-training-2021-02-04-16-47-39-189
