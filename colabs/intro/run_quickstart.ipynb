# %% [markdown]
# ## Use W&B to track, visualize, and manage machine learning experiments of any size.
#
# Install W&B to track, visualize, and manage machine learning experiments of any size.
#
# ## Install W&B Python SDK
#
# Install the W&B Python SDK (`wandb`) with your preferred Python package installer. This notebook uses `pip`:

# %%
# !pip install wandb

# %% [markdown]
# Next, import the W&B Python SDK and other Python packages we'll use in this notebook:

# %%
import wandb
from getpass import getpass
import random
import os

# %% [markdown]
# ## Log in
#
# To authenticate your machine with W&B, you need a W&B API key. Run the following cell and when prompted, enter your API key:

# %%
os.environ["WANDB_API_KEY"] = getpass("Enter your W&B API key: ")

# %% [markdown]
# ## Create a machine learning training experiment
#
# The following mock training script logs simulated accuracy and loss metrics to W&B.
#
# The script starts a run with [`wandb.init()`](https://docs.wandb.ai/models/ref/python/functions/init) and records it to the `"my-awesome-project"` project. It also passes a [`config`](https://docs.wandb.ai/models/track/config) dictionary that stores the run’s input parameters, including the number of epochs and learning rate.
#
# The training loop simulates eight epochs by iterating over `range(2, config["epochs"])`. Because `config["epochs"]` is set to `10`, the loop logs metrics for epochs `2` through `9`.
#
# For each epoch, the script logs simulated accuracy and loss values to W&B with `run.log()`.

# %%
# Project that the run is recorded to
project = "my-awesome-project"

# Dictionary with hyperparameters
config = {
    'epochs' : 10,
    'lr' : 0.01
}

with wandb.init(project=project, config=config) as run:
    offset = random.random() / 5
    print(f"lr: {config['lr']}")
    
    # Simulate a training run
    for epoch in range(2, config['epochs']):
        acc = 1 - 2**-config['epochs'] - random.random() / config['epochs'] - offset
        loss = 2**-config['epochs'] + random.random() / config['epochs'] + offset
        print(f"epoch={epoch}, accuracy={acc}, loss={loss}")
        run.log({"accuracy": acc, "loss": loss})

# %% [markdown]
# Click the `"View project at:"` link in the prior cell's output (or go to wandb.ai/home) to view your experiment. Each run appears in your project's **Workspace** and **Runs** page with auto-generated names.
